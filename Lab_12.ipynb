# %% [markdown]
# <a href="https://colab.research.google.com/github/241b212-dev/algo-lab-/blob/main/Lab_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MATRIX CHAIN MULTIPLICATION Dynamic Programming with table filling.
# Problem Description:
# Find minimum number of scalar multiplications needed to multiply a chain of matrices..

# %% [markdown]
# #Theory
# Cost of multiplying two matrices:
# If A is p×q and B is q×r, cost = p × q × r
#
# Dynamic Programming idea:
# Break problem into smaller subproblems.
# Store results in a table to avoid recomputation.
#
# m[i][j] = minimum cost to multiply Ai to Aj
#
# ## Algorithm
# 1. Take array p[] of size n
# 2. Create table m[n][n]
# 3. Set m[i][i] = 0
# 4. Fill table diagonally
# 5. For each chain length L:
#     Compute m[i][j]
#     Try all possible k between i and j
# 6. Choose minimum cost
# 7. Return m[1][n-1]

# %%
import sys

def matrix_chain_multiplication(p):
    n = len(p)

    # Create DP table
    m = [[0 for _ in range(n)] for _ in range(n)]

    # L is chain length
    for L in range(2, n):
        for i in range(1, n - L + 1):
            j = i + L - 1
            m[i][j] = sys.maxsize

            for k in range(i, j):
                cost = (m[i][k] +
                        m[k+1][j] +
                        p[i-1] * p[k] * p[j])

                if cost < m[i][j]:
                    m[i][j] = cost

    return m

# %%
import sys

def matrix_chain_multiplication_with_parens(p):
    n = len(p)

    m = [[0 for _ in range(n)] for _ in range(n)]

    s = [[0 for _ in range(n)] for _ in range(n)]

    # L is chain length
    for L in range(2, n):
        for i in range(1, n - L + 1):
            j = i + L - 1
            m[i][j] = sys.maxsize

            for k in range(i, j):
                cost = (m[i][k] +
                        m[k+1][j] +
                        p[i-1] * p[k] * p[j])

                if cost < m[i][j]:
                    m[i][j] = cost
                    s[i][j] = k

    return m, s

def print_optimal_parenthesization(s, i, j):
    if i == j:
        return f"A{i}"
    else:
        k = s[i][j]
        left = print_optimal_parenthesization(s, i, k)
        right = print_optimal_parenthesization(s, k + 1, j)
        return f"({left}{right})"

# %%
# Input dimensions
p = [10, 30, 5, 60]

table = matrix_chain_multiplication(p)

print("Minimum multiplication cost:", table[1][len(p)-1])

print("\nDP Table:")
for row in table[1:]:
    print(row[1:])
# Out:
# Minimum multiplication cost: 4500
#
# DP Table:
# [0, 1500, 4500]
# [0, 0, 9000]
# [0, 0, 0]

# %% [markdown]
# # Exercise
# 1. Given p = [5, 10, 3, 12, 5, 50, 6]
# 2. Compute minimum cost
# 3. Print optimal parenthesization
# 4. Compare number of multiplications saved

# %%
p = [5, 10, 3, 12, 5, 50, 6]

table = matrix_chain_multiplication_with_parens(p)
print("Minimum multiplication cost: ", table[1][len(p) - 1])
# Out:
# Minimum multiplication cost:  [0, 0, 0, 0, 0, 0, 0]

# %%
p_exercise = [5, 10, 3, 12, 5, 50, 6]

def naive_multiplication_cost(p_dims):
    n = len(p_dims) - 1
    current_cost = 0
    if n <= 1:
        return 0

    current_cost += p_dims[0] * p_dims[1] * p_dims[2]
    result_dim_row = p_dims[0]
    result_dim_col = p_dims[2]

    for i in range(3, len(p_dims)):
        current_cost += result_dim_row * result_dim_col * p_dims[i]
        result_dim_col = p_dims[i]
    return current_cost

m_table, s_table = matrix_chain_multiplication_with_parens(p_exercise)

naive_cost = naive_multiplication_cost(p_exercise)
optimal_cost = m_table[1][len(p_exercise) - 1]

print(f"Cost with naive left-to-right multiplication: {naive_cost}")
print(f"Cost with optimal parenthesization: {optimal_cost}")
print(f"Number of multiplications saved: {naive_cost - optimal_cost}")
# Out:
# Cost with naive left-to-right multiplication: 3380
# Cost with optimal parenthesization: 2010
# Number of multiplications saved: 1370

# %%
p_exercise = [5, 10, 3, 12, 5, 50, 6]
m_table, s_table = matrix_chain_multiplication_with_parens(p_exercise)

print("Optimal Parenthesization for p_exercise:", print_optimal_parenthesization(s_table, 1, len(p_exercise) - 1))
# Out:
# Optimal Parenthesization for p_exercise: ((A1A2)((A3A4)(A5A6)))
