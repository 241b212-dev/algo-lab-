# %% [markdown]
# <a href="https://colab.research.google.com/github/241b212-dev/algo-lab-/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
# Dijkstra with user input + path tracking

def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}

    distances[start] = 0
    visited = set()

    while len(visited) < len(graph):
        current = None
        min_dist = float('inf')

        # find minimum distance node
        for node in graph:
            if node not in visited and distances[node] < min_dist:
                min_dist = distances[node]
                current = node

        if current is None:
            break

        visited.add(current)

        # update neighbors
        for neighbor in graph[current]:
            new_dist = distances[current] + graph[current][neighbor]
            if new_dist < distances[neighbor]:
                distances[neighbor] = new_dist
                previous[neighbor] = current

    return distances, previous


# function to print shortest path
def print_path(previous, start, end):
    path = []
    current = end

    while current:
        path.append(current)
        current = previous[current]

    path.reverse()
    return path


# -------- USER INPUT --------
graph = {}

n = int(input("Enter number of nodes: "))

for _ in range(n):
    node = input("Enter node name: ")
    graph[node] = {}

    edges = int(input(f"Enter number of edges from {node}: "))
    for _ in range(edges):
        neighbor = input("  Enter neighbor: ")
        weight = int(input("  Enter weight: "))
        graph[node][neighbor] = weight


# -------- ADD TWO MORE NODES --------
print("\nAdd two more nodes:")
for _ in range(2):
    node = input("Enter new node: ")
    graph[node] = {}

    edges = int(input(f"Enter number of edges from {node}: "))
    for _ in range(edges):
        neighbor = input("  Enter neighbor: ")
        weight = int(input("  Enter weight: "))
        graph[node][neighbor] = weight


# -------- TEST WITH DIFFERENT SOURCE --------
while True:
    start = input("\nEnter source node (or 'exit' to stop): ")
    if start == "exit":
        break

    distances, previous = dijkstra(graph, start)

    print(f"\nShortest paths from {start}:")

    for node in graph:
        path = print_path(previous, start, node)
        print(f"{start} -> {node} = {distances[node]}, Path: {' -> '.join(path)}")
# Out:
# Enter number of nodes: 4
# Enter node name: A
# Enter number of edges from A: 2
#   Enter neighbor: B
#   Enter weight: 2
#   Enter neighbor: C
#   Enter weight: 4
# Enter node name: B
# Enter number of edges from B: 3
#   Enter neighbor: A
#   Enter weight: 2
#   Enter neighbor: C
#   Enter weight: 1
#   Enter neighbor: D
#   Enter weight: 7
# Enter node name: C
# Enter number of edges from C: 3
#   Enter neighbor: A
#   Enter weight: 4
#   Enter neighbor: B
#   Enter weight: 1
#   Enter neighbor: D
#   Enter weight: 3
# Enter node name: D
# Enter number of edges from D: 2
#   Enter neighbor: B
#   Enter weight: 7
#   Enter neighbor: C
#   Enter weight: 3
#
# Add two more nodes:
# Enter new node: E
# Enter number of edges from E: 2
#   Enter neighbor: B
#   Enter weight: 5
#   Enter neighbor: D
#   Enter weight: 2
# Enter new node: F
# Enter number of edges from F: 1
#   Enter neighbor: E
#   Enter weight: 1
#
# Enter source node (or 'exit' to stop): A
#
# Shortest paths from A:
# A -> A = 0, Path: A
# A -> B = 2, Path: A -> B
# A -> C = 3, Path: A -> B -> C
# A -> D = 6, Path: A -> B -> C -> D
# A -> E = inf, Path: E
# A -> F = inf, Path: F
#
# Enter source node (or 'exit' to stop): B
#
# Shortest paths from B:
# B -> A = 2, Path: B -> A
# B -> B = 0, Path: B
# B -> C = 1, Path: B -> C
# B -> D = 4, Path: B -> C -> D
# B -> E = inf, Path: E
# B -> F = inf, Path: F
#
# Enter source node (or 'exit' to stop): E
#
# Shortest paths from E:
# E -> A = 7, Path: E -> B -> A
# E -> B = 5, Path: E -> B
# E -> C = 5, Path: E -> D -> C
# E -> D = 2, Path: E -> D
# E -> E = 0, Path: E
# E -> F = inf, Path: F
#
# Enter source node (or 'exit' to stop): exit
